# %%
# %%capture
# !wget "https://www.dropbox.com/s/35ithckx6vqryob/Monkeys_Faces_Dataset.tar?dl=0" -O Monkeys_Faces_Dataset.tar  
# !tar --warning=no-unknown-keyword -xzf Monkeys_Faces_Dataset.tar

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 32  #batch size: if your GPU is running out of memory, set a smaller batch size, i.e 16
sz = 224 #image size
PATH = './MF/'

# %%
classes = []
for d in os.listdir(PATH):
    if os.path.isdir(os.path.join(PATH, d)) and not d.startswith('.'):
        classes.append(d) 
print ("There are ", len(classes), "classes:\n", classes)
# Out:
# There are  10 classes:
#  ['bald uakari', 'black headed night monkey', 'common squirell monkey', 'japanese macaque', 'mantled howler', 'nilgiri langur', 'patas monkey', 'pygmy marmoset', 'silvery marmoset', 'white headed capuchin']

# %%
for c in classes:
    print ("Class:", c)
    verify_images(os.path.join(PATH, c), delete=True);
# Out:
# Class: bald uakari
# Class: black headed night monkey
# Class: common squirell monkey
# Class: japanese macaque
# Class: mantled howler
# Class: nilgiri langur
# Class: patas monkey
# Class: pygmy marmoset
# Class: silvery marmoset
# Class: white headed capuchin

# %%
data  = ImageDataBunch.from_folder(PATH, ds_tfms=get_transforms(), size=sz, bs=bs, valid_pct=0.2).normalize(imagenet_stats)

# %%
print ("There are", len(data.train_ds), "training images and", len(data.valid_ds), "validation images." )
# Out:
# There are 878 training images and 219 validation images.

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.lr_find();
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='3' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       75.00% [3/4 27:27<09:09]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.766014</td>
#       <td>#na#</td>
#       <td>13:34</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.034385</td>
#       <td>#na#</td>
#       <td>08:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.113972</td>
#       <td>#na#</td>
#       <td>05:47</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='7' class='' max='27', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       25.93% [7/27 01:39<04:43 6.4623]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(4, max_lr=slice(1e-3,1e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.920712</td>
#       <td>0.048566</td>
#       <td>0.986301</td>
#       <td>06:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.445854</td>
#       <td>0.081877</td>
#       <td>0.972603</td>
#       <td>06:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.271370</td>
#       <td>0.039016</td>
#       <td>0.977169</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.167184</td>
#       <td>0.039744</td>
#       <td>0.981735</td>
#       <td>06:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
#interp.plot_top_losses(1, figsize=(15,11), heatmap=False)

# %%
path = './validation/n0/' #The path of your test image
img = open_image(get_image_files(path)[0])
pred_class,pred_idx,outputs = learn.predict(img)
img.show()
print ("It is a", pred_class)
# Out:
# It is a mantled howler

# %%
path = './validation/n1/' #The path of your test image
img = open_image(get_image_files(path)[0])
pred_class,pred_idx,outputs = learn.predict(img)
img.show()
print ("It is a", pred_class)
# Out:
# It is a patas monkey
